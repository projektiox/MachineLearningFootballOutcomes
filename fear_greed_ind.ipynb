# %%
import requests

url = "https://fear-and-greed-index.p.rapidapi.com/v1/fgi"

headers = {
	"x-rapidapi-key": "b1b7e32aecmsh159daf694124df0p1706d3jsn4fe02bc48de4",
	"x-rapidapi-host": "fear-and-greed-index.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'lastUpdated': {'epochUnixSeconds': 1753112480, 'humanDate': '2025-07-21T15:41:20.000Z'}, 'fgi': {'now': {'value': 76, 'valueText': 'Extreme Greed'}, 'previousClose': {'value': 75, 'valueText': 'Extreme Greed'}, 'oneWeekAgo': {'value': 76, 'valueText': 'Extreme Greed'}, 'oneMonthAgo': {'value': 54, 'valueText': 'Neutral'}, 'oneYearAgo': {'value': 43, 'valueText': 'Fear'}}}
